# %%
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib
# %pip install jinja2
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# ==========================================
# CELL 1: CLOUD INGESTION & MASTER DATASET
# ==========================================
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

print("1. Downloading raw datasets directly from GitHub...\n")

base_url = "https://github.com/kori0494/datathon_work/tree/main/data"

# All the required CSV files
file_names = {
    'orders': 'orders.csv', 'order_items': 'order_items.csv',
    'products': 'products.csv', 'customers': 'customers.csv',
    'promotions': 'promotions.csv', 'returns': 'returns.csv',
    'geography': 'geography.csv', 'shipments': 'shipments.csv',
    'payments': 'payments.csv', 'reviews': 'reviews.csv',
    'inventory': 'inventory.csv', 'web_traffic': 'web_traffic.csv',
    'sales': 'sales.csv'
}

tables = {}
for name, filename in file_names.items():
    file_url = f"{base_url}{filename}"
    try:
        tables[name] = pd.read_csv(file_url)
        print(f" {name.ljust(12)} loaded ({tables[name].shape[0]:,} rows)")
    except Exception as e:
        print(f" {name.ljust(12)} missing or failed to load. Check GitHub.")

print("\n2. Assembling the Item-Level Master Dataset...\n")

# 1. Base Table: Order Items (Granularity: 1 row per product sold)
df = tables.get('order_items').copy()

# 2. Merge Orders (Provides order_date, zip)
if 'orders' in tables:
    df = df.merge(tables['orders'], on='order_id', how='left')

# 3. Merge Products (Provides category, segment, cogs)
if 'products' in tables:
    df = df.merge(tables['products'], on='product_id', how='left')

# 4. Merge Promotions
if 'promo_id' in df.columns and 'promotions' in tables:
    df = df.merge(tables['promotions'], on='promo_id', how='left')

# 5. Merge Customers (Drop duplicate geographic columns first to prevent _x/_y bugs)
if 'customer_id' in df.columns and 'customers' in tables:
    cust_clean = tables['customers'].drop(columns=['zip', 'city'], errors='ignore')
    df = df.merge(cust_clean, on='customer_id', how='left')

# 6. Merge Geography
if 'zip' in df.columns and 'geography' in tables:
    df = df.merge(tables['geography'], on='zip', how='left')

# 7. Merge Shipments
if 'order_id' in df.columns and 'shipments' in tables:
    df = df.merge(tables['shipments'], on='order_id', how='left')

# 8. Merge Returns (Aggregated at the Order-Product level to prevent duplicate rows)
if 'returns' in tables:
    returns_agg = tables['returns'].groupby(['order_id', 'product_id'])['refund_amount'].sum().reset_index()
    df = df.merge(returns_agg, on=['order_id', 'product_id'], how='left')

print("3. Calculating Financial Metrics (Net Revenue & Profit)...\n")

# Safely handle missing values in financial columns before math
df['discount_amount'] = df['discount_amount'].fillna(0)
if 'refund_amount' in df.columns:
    df['refund_amount'] = df['refund_amount'].fillna(0)
else:
    df['refund_amount'] = 0

# Gross Metrics
df['Gross_Revenue'] = (df['quantity'] * df['unit_price']) - df['discount_amount']
df['Gross_Profit'] = df['Gross_Revenue'] - (df['quantity'] * df.get('cogs', 0))

# Net Metrics (With Returns Deducted!)
df['Net_Revenue'] = np.clip(df['Gross_Revenue'] - df['refund_amount'], 0, None)
df['Net_Profit'] = df['Gross_Profit'] - df['refund_amount']

print(f"Cloud Ingestion Complete! Master Dataset Shape: {df.shape[0]:,} rows and {df.shape[1]} columns.")
# Out:
# 1. Downloading raw datasets directly from GitHub...

# %%
from typing import Dict, Any


def profile_dataframe(name: str, tbl_df: pd.DataFrame) -> Dict[str, Any]:
    
    # 1. Datetime Handling
    date_cols = tbl_df.select_dtypes(include=['datetime', 'datetimetz']).columns
    
    if len(date_cols) > 0:
        min_date = tbl_df[date_cols].min().min().strftime('%Y-%m-%d')
        max_date = tbl_df[date_cols].max().max().strftime('%Y-%m-%d')
        date_range = f"{min_date} ➔ {max_date}"
    else:
        date_range = "N/A"
        
    # 2. Missing Value Formatting
    missing_pct = (tbl_df.isnull().sum() / len(tbl_df)) * 100
    missing_pct = missing_pct[missing_pct > 0].sort_values(ascending=False).round(1)
    
    if not missing_pct.empty:
        top_missing_str = ", ".join([f"{col} ({pct}%)" for col, pct in missing_pct.head(3).items()])
        if len(missing_pct) > 3:
            top_missing_str += " ..."
    else:
        top_missing_str = "Clean"
        
    # 3. Accurate Memory Calculation
    mem_mb = tbl_df.memory_usage(deep=True).sum() / (1024 * 1024)
    
    return {
        'Table Name': name.title().replace('_', ' '),
        'Rows': tbl_df.shape[0],
        'Columns': tbl_df.shape[1],
        'Memory (MB)': round(mem_mb, 2),
        'Date Range': date_range,
        'Cols w/ Missing': len(missing_pct),
        'Top Missing Features': top_missing_str,
        'Duplicates': int(tbl_df.duplicated().sum())
    }

print("Auditing all individual datasets for quality...\n")

audit_records = [profile_dataframe(name, tbl_df) for name, tbl_df in tables.items() if tbl_df is not None]

# Convert the results into a DataFrame
quality_df = pd.DataFrame(audit_records)

#Styling
styled_quality_report = (
    quality_df.style
    .format({'Rows': '{:,}'}) # Adds commas to large numbers
    .background_gradient(subset=['Cols w/ Missing', 'Duplicates'], cmap='Reds') # Highlights bad data
    .background_gradient(subset=['Memory (MB)'], cmap='Blues') # Highlights large files
    .set_caption("<b>Data Quality & Memory Audit Report</b>")
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '16px'), ('font-family', 'sans-serif')]
    }])
)

display(styled_quality_report)

# %%
print("Re-building the Master Dataset with full dimensions...\n")

# 1. Khởi tạo từ order_items (Granularity thấp nhất)
df = tables.get('order_items').copy()

# 2. Join Orders (Quan trọng: Join orders TRƯỚC để lấy promo_id)
if tables.get('orders') is not None:
    df = df.merge(tables.get('orders'), on='order_id', how='left')

# 3. Join Promotions (Bây giờ df đã có promo_id từ orders)
if tables.get('promotions') is not None and 'promo_id' in df.columns:
    df = df.merge(tables.get('promotions'), on='promo_id', how='left')

# 4. Join Products & Inventory (Chiều Vận Hành)
if tables.get('products') is not None:
    df = df.merge(tables.get('products'), on='product_id', how='left')
if tables.get('inventory') is not None and 'product_id' in df.columns:
    df = df.merge(tables.get('inventory'), on='product_id', how='left')

# 5. Join Customers & Geography (Chiều Địa Lý)
if tables.get('customers') is not None:
    df = df.merge(tables.get('customers'), on='customer_id', how='left')
if tables.get('geography') is not None and 'zip' in df.columns:
    df = df.merge(tables.get('geography'), on='zip', how='left')

# 6. Join Shipments (Chiều Vận Hành)
if tables.get('shipments') is not None:
    df = df.merge(tables.get('shipments'), on='order_id', how='left')

# 7. Tính Toán CƠ BẢN (Revenue & COGS ban đầu)
df['discount_amount'] = df['discount_amount'].fillna(0)
df['Gross_Revenue'] = (df['quantity'] * df['unit_price']) - df['discount_amount']

if 'cogs' in df.columns:
    df['COGS'] = df['quantity'] * df['cogs']
    df['Gross_Profit'] = df['Gross_Revenue'] - df['COGS']

# 8. JOIN RETURNS VÀ KHẤU TRỪ LỢI NHUẬN (BƯỚC QUAN TRỌNG NHẤT)
returns = tables.get('returns')
if returns is not None:
    # Lấy số tiền hoàn trả cho mỗi đơn hàng
    returns_clean = returns[['order_id', 'refund_amount']].groupby('order_id').sum().reset_index()
    df = df.merge(returns_clean, on='order_id', how='left')
    df['refund_amount'] = df['refund_amount'].fillna(0)
    
    # Net Revenue và Net Profit thực tế sau khi trừ đi hàng hoàn trả
    df['Net_Revenue'] = df['Gross_Revenue'] - df['refund_amount']
    df['Net_Profit'] = df['Gross_Profit'] - df['refund_amount']
    
    # Những đơn hàng bị hoàn trả toàn bộ có thể sinh ra doanh thu âm, set min = 0
    df['Net_Revenue'] = np.clip(df['Net_Revenue'], 0, None)
else:
    df['Net_Revenue'] = df['Gross_Revenue']
    df['Net_Profit'] = df['Gross_Profit']

print(f"Master Dataset v2 created! Shape: {df.shape[0]:,} rows and {df.shape[1]} columns.")
print("Return Deductions Applied: 'Net_Revenue' and 'Net_Profit' are now safe to use.")

# %%
#Feature Tabulation
import pandas as pd
import numpy as np

print("Calculating core business metrics (Revenue, COGS, Profit)...")

# 1. Calculate Target Variables (Crucial for the Datathon!)
# Revenue = (Quantity * Price) - Discount
df['discount_amount'] = df['discount_amount'].fillna(0)
df['Revenue'] = (df['quantity'] * df['unit_price']) - df['discount_amount']

# COGS (Cost of Goods Sold) = Quantity * Unit Cost
if 'cogs' in df.columns:
    df['COGS'] = df['quantity'] * df['cogs']
    df['Profit'] = df['Revenue'] - df['COGS']

# PART A: NUMERICAL SUMMARY (THE BUSINESS METRICS)
print("\n--- 1. NUMERICAL DISTRIBUTION SUMMARY ---")

# Select only the most important numeric columns for business
numeric_cols = ['quantity', 'unit_price', 'discount_amount', 'Revenue', 'COGS', 'Profit']
existing_num_cols = [col for col in numeric_cols if col in df.columns]

# Calculate the statistics
num_summary = df[existing_num_cols].describe().T

# Drop the 'count' column (we know how big the dataset is) and round things
num_summary = num_summary.drop('count', axis=1).round(2)

# Style it beautifully for the judges
styled_num = (
    num_summary.style
    .format("{:,.2f}") # Add commas for thousands (e.g., 10,000.00)
    .background_gradient(subset=['mean', '50%', 'max'], cmap='Greens') # Heatmap for highs
    .background_gradient(subset=['min'], cmap='Reds') # Heatmap for lows (e.g., negative profit)
    .set_caption("<b>Key Financial Distributions</b>")
    .set_table_styles([{'selector': 'caption', 'props': [('font-size', '16px')]}])
)
display(styled_num)

# PART B: CATEGORICAL SUMMARY (THE BUSINESS SEGMENTS)

print("\n--- 2. CATEGORICAL SEGMENT SUMMARY ---")

# Select interesting categorical features
cat_cols = ['order_status', 'payment_method', 'device_type', 'category', 'segment', 'promo_type']
existing_cat_cols = [col for col in cat_cols if col in df.columns]

# Build a custom summary dataframe
cat_summary = pd.DataFrame(index=existing_cat_cols)
cat_summary['Unique Categories'] = [df[col].nunique() for col in existing_cat_cols]
cat_summary['Top Category (Mode)'] = [df[col].mode()[0] for col in existing_cat_cols]
cat_summary['Top % Share'] = [round((df[col].value_counts(normalize=True).iloc[0] * 100), 1) for col in existing_cat_cols]

# Format the percentage column to look like "45.2%"
cat_summary['Top % Share'] = cat_summary['Top % Share'].astype(str) + "%"

# Style the categorical table
styled_cat = (
    cat_summary.style
    .background_gradient(subset=['Unique Categories'], cmap='Purples')
    .set_caption("<b>Categorical Feature Dominance</b>")
    .set_table_styles([{'selector': 'caption', 'props': [('font-size', '16px')]}])
)
display(styled_cat)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Generating the Essential 6-Chart EDA Suite...")

fig, axes = plt.subplots(3, 2, figsize=(20, 18), facecolor='#f8f9fa')
fig.suptitle('Master Dataset EDA: Business Insights & Diagnostics', fontsize=22, fontweight='bold', y=0.98)

df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# 1. Revenue Time Series
daily_rev = df.groupby('order_date')['Net_Revenue'].sum().reset_index()
sns.lineplot(data=daily_rev, x='order_date', y='Net_Revenue', ax=axes[0,0], color='#2A9D8F')
axes[0,0].set_title('1. Daily Net Revenue Trend', fontweight='bold')
axes[0,0].set_ylabel('Net Revenue ($)')

# 2. Category Breakdown
cat_rev = df.groupby('category')['Net_Revenue'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=cat_rev.values, y=cat_rev.index, ax=axes[0,1], palette='Blues_r')
axes[0,1].set_title('2. Top Categories by Net Revenue', fontweight='bold')
axes[0,1].set_xlabel('Net Revenue ($)')

# 3. Customer Segmentation
seg_counts = df['segment'].value_counts()
axes[1,0].pie(seg_counts, labels=seg_counts.index, autopct='%1.1f%%', colors=['#E76F51', '#F4A261', '#E9C46A'])
axes[1,0].set_title('3. Customer Segmentation Share', fontweight='bold')

# 4. Return Rate Analysis
df['is_returned'] = (df['refund_amount'] > 0).astype(int)
return_rate = df.groupby('category')['is_returned'].mean().sort_values(ascending=False).head(10) * 100
sns.barplot(x=return_rate.values, y=return_rate.index, ax=axes[1,1], palette='Reds_r')
axes[1,1].set_title('4. Highest Return Rates by Category (%)', fontweight='bold')
axes[1,1].set_xlabel('Return Rate (%)')

# 5. Geographic Heatmap
city_rev = df.groupby('city')['Net_Revenue'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=city_rev.values, y=city_rev.index, ax=axes[2,0], palette='Greens_r')
axes[2,0].set_title('5. Geographic Revenue Hotspots (Top Cities)', fontweight='bold')
axes[2,0].set_xlabel('Net Revenue ($)')

# 6. Correlation Heatmap
numeric_cols = ['quantity', 'unit_price', 'discount_amount', 'Gross_Revenue', 'refund_amount', 'Net_Profit']
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[2,1], vmin=-1, vmax=1)
axes[2,1].set_title('6. Financial Correlation Heatmap', fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('comprehensive_eda_dashboard.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
print("Initiating Data Cleaning & Feature Engineering...\n")

# ---------------------------------------------------------
# 1. BUSINESS LOGIC IMPUTATION (Preserving Revenue!)
# ---------------------------------------------------------
print("Fixing missing values using business rules...")

# If a promo column is missing, it simply means the customer paid full organic price.
promo_fill_rules = {
    'promo_id': 'No Promo',
    'promo_id_2': 'No Promo',
    'promo_name': 'None',
    'promo_type': 'None',
    'discount_value': 0.0,
    'applicable_category': 'All',
    'promo_channel': 'None',
    'min_order_value': 0.0
}

# Apply the rules safely to preserve all revenue rows
for col, fill_val in promo_fill_rules.items():
    if col in df.columns:
        df[col] = df[col].fillna(fill_val)

# Handle missing geographical or customer data
geo_cols = ['zip', 'city', 'region', 'district', 'gender', 'age_group', 'acquisition_channel']
for col in geo_cols:
    if col in df.columns:
        df[col] = df[col].fillna('Unknown')

        
# ---------------------------------------------------------
# 2. TIME-SERIES FEATURE ENGINEERING 
# ---------------------------------------------------------
print("Generating Time-Series features from 'order_date'...")

if 'order_date' in df.columns:
    # Ensure it is a datetime object
    df['order_date'] = pd.to_datetime(df['order_date'])
    
    # Extract standard temporal features
    df['year'] = df['order_date'].dt.year
    df['month'] = df['order_date'].dt.month
    df['day'] = df['order_date'].dt.day
    df['day_of_week'] = df['order_date'].dt.dayofweek # Monday=0, Sunday=6
    df['quarter'] = df['order_date'].dt.quarter
    df['day_of_year'] = df['order_date'].dt.dayofyear
    
    # Extract behavioral flags
    df['is_weekend'] = np.where(df['day_of_week'] >= 5, 1, 0)
    
    df['is_month_end'] = df['order_date'].dt.is_month_end.astype(int)


# Check if we successfully eliminated all missing values
remaining_missing = df.isnull().sum()
total_missing = remaining_missing.sum()

if total_missing == 0:
    print("Cleaning Complete! The Master Dataset has ZERO missing values.")
else:
    print(f"Warning: There are still {total_missing} missing values remaining.")
    print(remaining_missing[remaining_missing > 0])

# Display the new Time-Series features for the Judges
print("\n--- Newly Engineered Time-Series Features ---")
ts_cols = ['order_date', 'year', 'month', 'day_of_week', 'is_weekend', 'is_month_end', 'Revenue']
existing_ts_cols = [c for c in ts_cols if c in df.columns]

display(df[existing_ts_cols].head())
